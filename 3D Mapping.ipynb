# %%
import Pkg
Pkg.add("Plotly")
;

import Pkg
Pkg.add("ProgressMeter")
;

import Pkg
Pkg.add("PyPlot")
;
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
using JuMP, Plots

X = [1 1 1; 2 2 2]
Y = [2 2 2; 3 3 3]
Z = [3 3 3; 4 4 4]

scatter(X, Y, Z)
# Out:
# MethodError: no method matching getproperty(::Figure, ::String)
# Closest candidates are:
#   getproperty(!Matched::PyCall.PyObject, ::AbstractString) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/PyCall.jl:302
#   getproperty(::Any, !Matched::Symbol) at sysimg.jl:18
#   getproperty(::Any, !Matched::Type{T}, !Matched::Int64, !Matched::Symbol) where T at /Users/alexpletta/.julia/packages/Tables/MZdkP/src/utils.jl:26
#
# Stacktrace:
#  [1] _before_layout_calcs(::Plots.Plot{Plots.PyPlotBackend}) at /Users/alexpletta/.julia/packages/Plots/47Tik/src/backends/pyplot.jl:940
#  [2] prepare_output(::Plots.Plot{Plots.PyPlotBackend}) at /Users/alexpletta/.julia/packages/Plots/47Tik/src/plot.jl:254
#  [3] show(::Base64.Base64EncodePipe, ::MIME{Symbol("image/png")}, ::Plots.Plot{Plots.PyPlotBackend}) at /Users/alexpletta/.julia/packages/Plots/47Tik/src/output.jl:197
#  [4] #base64encode#3(::Nothing, ::Function, ::Function, ::MIME{Symbol("image/png")}, ::Vararg{Any,N} where N) at /Users/osx/buildbot/slave/package_osx64/build/usr/share/julia/stdlib/v1.0/Base64/src/encode.jl:206
#  [5] base64encode(::Function, ::MIME{Symbol("image/png")}, ::Vararg{Any,N} where N) at /Users/osx/buildbot/slave/package_osx64/build/usr/share/julia/stdlib/v1.0/Base64/src/encode.jl:203
#  [6] _ijulia_display_dict(::Plots.Plot{Plots.PyPlotBackend}) at /Users/alexpletta/.julia/packages/Plots/47Tik/src/ijulia.jl:47
#  [7] display_dict(::Plots.Plot{Plots.PyPlotBackend}) at /Users/alexpletta/.julia/packages/Plots/47Tik/src/init.jl:42
#  [8] #invokelatest#1 at ./essentials.jl:697 [inlined]
#  [9] invokelatest at ./essentials.jl:696 [inlined]
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/alexpletta/.julia/packages/IJulia/GIANC/src/execute_request.jl:97
#  [11] #invokelatest#1 at ./essentials.jl:697 [inlined]
#  [12] invokelatest at ./essentials.jl:696 [inlined]
#  [13] eventloop(::ZMQ.Socket) at /Users/alexpletta/.julia/packages/IJulia/GIANC/src/eventloop.jl:8
#  [14] (::getfield(IJulia, Symbol("##15#18")))() at ./task.jl:259

# %%
# Learn about API authentication here: https://plot.ly/julia/getting-started
# Find your api_key here: https://plot.ly/settings/api

using Plotly


data = [
  [
response = Plotly.plot(data, ["layout" =&gt; layout, "filename" =&gt; "elevations-3d-surface", "fileopt" =&gt; "overwrite"])
plot_url = response["url"]
# Out:
# ┌ Info: Recompiling stale cache file /Users/alexpletta/.julia/compiled/v1.0/Plotly/M5iCk.ji for Plotly [58dd65bb-95f3-509e-9936-c39a10fdeae7]
# └ @ Base loading.jl:1190
# WARNING: could not import Base.quit into AtomShell
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-9457195791738554613\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-1291732520829823811\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio/main\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n        console.warn(\"Loading WebIO Jupyter extension on an ad-hoc basis. Consider enabling the WebIO nbextension for a stabler experience (this should happen automatically when building WebIO).\");\n        require([\"/assetserver/3c1933ca3c2fefb0fd1e2ba3424cb2659125f258-dist/main.js\"], function (webIOModule) {\n            webIOModule.load_ipython_extension();\n        });\n        warning_div.innerHTML = \"<strong>Loading WebIO Jupyter extension on an ad-hoc basis. Consider enabling the WebIO nbextension for a stabler experience (this should happen automatically when building WebIO).</strong>\";\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<div\n    id=\"webio-warning-9457195791738554613\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    <!-- TODO: link to installation docs. -->\n</div>\n")
# syntax: unexpected comma in matrix expression

# %%
using Plots

x = y = LinRange(-5, 5, 30)
z = sin(sqrt(Float64[xi^2+yi^2 for xi=x, yi=y]));
surf(x,y,z,α=0.7)
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'AttributeError'>
# AttributeError('Unknown property α')
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py", line 1693, in plot_surface
#     polyc = art3d.Poly3DCollection(polys, *args, **kwargs)
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py", line 526, in __init__
#     super().__init__(verts, *args, **kwargs)
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/matplotlib/collections.py", line 933, in __init__
#     Collection.__init__(self, **kwargs)
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/matplotlib/collections.py", line 166, in __init__
#     self.update(kwargs)
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/matplotlib/artist.py", line 916, in update
#     ret = [_update_property(self, k, v) for k, v in props.items()]
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/matplotlib/artist.py", line 916, in <listcomp>
#     ret = [_update_property(self, k, v) for k, v in props.items()]
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/matplotlib/artist.py", line 912, in _update_property
#     raise AttributeError('Unknown property %s' % k)
#
#
# Stacktrace:
#  [1] pyerr_check at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/exception.jl:60 [inlined]
#  [2] pyerr_check at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/exception.jl:64 [inlined]
#  [3] macro expansion at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/exception.jl:84 [inlined]
#  [4] __pycall!(::PyCall.PyObject, ::Ptr{PyCall.PyObject_struct}, ::PyCall.PyObject, ::PyCall.PyObject) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44
#  [5] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{Array{Float64,2},Array{Float64,2},Array{Complex{Float64},2}}, ::Int64, ::PyCall.PyObject) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:29
#  [6] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{Array{Float64,2},Array{Float64,2},Array{Complex{Float64},2}}, ::Base.Iterators.Pairs{Symbol,Float64,Tuple{Symbol},NamedTuple{(:α,),Tuple{Float64}}}) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:11
#  [7] #pycall#110(::Base.Iterators.Pairs{Symbol,Float64,Tuple{Symbol},NamedTuple{(:α,),Tuple{Float64}}}, ::Function, ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Array{Float64,2}, ::Vararg{Any,N} where N) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:86
#  [8] (::getfield(PyCall, Symbol("#kw##pycall")))(::NamedTuple{(:α,),Tuple{Float64}}, ::typeof(PyCall.pycall), ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Array{Float64,2}, ::Vararg{Any,N} where N) at ./none:0
#  [9] #plot_surface#173(::Base.Iterators.Pairs{Symbol,Float64,Tuple{Symbol},NamedTuple{(:α,),Tuple{Float64}}}, ::Function, ::Array{Float64,2}, ::Vararg{Any,N} where N) at /Users/alexpletta/.julia/packages/PyPlot/mQXSC/src/plot3d.jl:50
#  [10] #plot_surface at ./none:0 [inlined]
#  [11] #surf#185 at /Users/alexpletta/.julia/packages/PyPlot/mQXSC/src/plot3d.jl:78 [inlined]
#  [12] #surf at ./none:0 [inlined]
#  [13] #surf#191 at /Users/alexpletta/.julia/packages/PyPlot/mQXSC/src/PyPlot.jl:248 [inlined]
#  [14] (::getfield(PyPlot, Symbol("#kw##surf")))(::NamedTuple{(:α,),Tuple{Float64}}, ::typeof(surf), ::LinRange{Float64}, ::LinRange{Float64}, ::Array{Complex{Float64},2}) at ./none:0
#  [15] top-level scope at In[68]:5

# %%
using PyPlot
x = -5:0.25:5
y = x'
R = sqrt(x.^2 .+ y.^2)
Z = sin(R)
surf(x,y,Z, facecolors=get_cmap("jet"), linewidth=0, antialiased=false)
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'TypeError'>
# TypeError("'LinearSegmentedColormap' object does not support indexing")
#   File "/Users/alexpletta/.julia/conda/3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py", line 1675, in plot_surface
#     colset.append(fcolors[rs][cs])
#
#
# Stacktrace:
#  [1] pyerr_check at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/exception.jl:60 [inlined]
#  [2] pyerr_check at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/exception.jl:64 [inlined]
#  [3] macro expansion at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/exception.jl:84 [inlined]
#  [4] __pycall!(::PyCall.PyObject, ::Ptr{PyCall.PyObject_struct}, ::PyCall.PyObject, ::PyCall.PyObject) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44
#  [5] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},LinearAlgebra.Adjoint{Float64,StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},Array{Complex{Float64},2}}, ::Int64, ::PyCall.PyObject) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:29
#  [6] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},LinearAlgebra.Adjoint{Float64,StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},Array{Complex{Float64},2}}, ::Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol,Symbol},NamedTuple{(:facecolors, :linewidth, :antialiased),Tuple{ColorMap,Int64,Bool}}}) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:11
#  [7] #pycall#110(::Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol,Symbol},NamedTuple{(:facecolors, :linewidth, :antialiased),Tuple{ColorMap,Int64,Bool}}}, ::Function, ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Vararg{Any,N} where N) at /Users/alexpletta/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:86
#  [8] (::getfield(PyCall, Symbol("#kw##pycall")))(::NamedTuple{(:facecolors, :linewidth, :antialiased),Tuple{ColorMap,Int64,Bool}}, ::typeof(PyCall.pycall), ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Vararg{Any,N} where N) at ./none:0
#  [9] #plot_surface#173(::Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol,Symbol},NamedTuple{(:facecolors, :linewidth, :antialiased),Tuple{ColorMap,Int64,Bool}}}, ::Function, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Vararg{Any,N} where N) at /Users/alexpletta/.julia/packages/PyPlot/mQXSC/src/plot3d.jl:50
#  [10] #plot_surface at ./none:0 [inlined]
#  [11] #surf#185 at /Users/alexpletta/.julia/packages/PyPlot/mQXSC/src/plot3d.jl:78 [inlined]
#  [12] (::getfield(PyPlot, Symbol("#kw##surf")))(::NamedTuple{(:facecolors, :linewidth, :antialiased),Tuple{ColorMap,Int64,Bool}}, ::typeof(surf), ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::LinearAlgebra.Adjoint{Float64,StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}}, ::Array{Complex{Float64},2}) at ./none:0
#  [13] top-level scope at In[69]:6

# %%
using Plots, ProgressMeter
pyplot(leg=false, ticks=nothing) #change to the pyplot backend and define some defaults
x = y = range(-5, stop = 5, length = 40)
zs = zeros(0,40)
n = 100

# create a progress bar for tracking the animation generation
prog = Progress(n,1)

@gif for i in range(0, stop = 2π, length = n)
    f(x,y) = sin(x + 10sin(i)) + cos(y)

    # create a plot with 3 subplots and a custom layout
    l = @layout [a{0.7w} b; c{0.2h}]
    p = plot(x, y, f, st = [:surface, :contourf], layout=l)

    # induce a slight oscillating camera angle sweep, in degrees (azimuth, altitude)
    plot!(p[1], camera=(15*cos(i), 40))

    # add a tracking line
    fixed_x = zeros(40)
    z = map(f, fixed_x, y)
    plot!(p[1], fixed_x, y, z, line = (:black, 5, 0.2))
    vline!(p[2], [0], line = (:black, 5))

    # add to and show the tracked values over time
    global zs = vcat(zs, z')
    plot!(p[3], zs, alpha = 0.2, palette = cgrad(:blues).colors)

    # increment the progress bar
    next!(prog)
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:37
# PyPlot.Figure(PyObject <Figure size 600x400 with 3 Axes>)
# ┌ Info: Saved animation to
# │   fn = /Users/alexpletta/Documents/Intro to Optimization/Optimization_PathPlanning/tmp.gif
# └ @ Plots /Users/alexpletta/.julia/packages/Plots/47Tik/src/animation.jl:90
# Plots.AnimatedGif("/Users/alexpletta/Documents/Intro to Optimization/Optimization_PathPlanning/tmp.gif")

# %%
x = 1:0.5:20
y = 1:0.5:10
f(x, y) = begin
        (3x + y ^ 2) * abs(sin(x) + cos(y))
    end
X = repeat(reshape(x, 1, :), length(y), 1)
Y = repeat(y, 1, length(x))
Z = map(f, X, Y)
p1 = contour(x, y, f, fill=true)
p2 = contour(x, y, Z)
plot(p1, p2)
# Out:
# WARNING: both Plotly and Plots export "contour"; uses of it in module Main must be qualified
# UndefVarError: contour not defined
#
# Stacktrace:
#  [1] top-level scope at In[3]:9

# %%
using PyPlot

plot(1, 2)
# Out:
# UndefVarError: plot not defined
#
# Stacktrace:
#  [1] top-level scope at In[72]:2

# %%
using JuMP, Gurobi, PyPlot, Ipopt

# Testing segment crossing
a = [1 1] # left point of ab
b = [2 2] # right point of ab
c = [2 0] # left point of cd
d = [1 2] # right point of cd

# segment ab
line1 = [a[1] b[1];
         a[2] b[2]]
# segment cd
line2 = [c[1] d[1];
         c[2] d[2]]

# Plot segments
plot(line1[1,:], line1[2,:], color="blue", label="ab")
plot(line2[1,:], line2[2,:], color="orange", label="cd")

title("Segments Crossing")
xlabel("x")
ylabel("y")
legend()
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# No handles with labels found to put in legend.
